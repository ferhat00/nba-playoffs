# %% [markdown]
# # NBA Playoff Predictor — Kaggle (P100 GPU)
#
# Clones https://github.com/ferhat00/nba-playoffs (main), applies runtime CUDA monkey-patches, and runs the full pipeline.
#
# **Before running:** in Kaggle notebook settings set **Accelerator = GPU P100** and **Internet = On** (`nba_api` needs network; fallback data exists but real data is better).
#
# ### Why P100 (not T4x2, not TPU)
# The critical path is PyMC MCMC on the Bayesian player evaluator; switching to `nuts_sampler="numpyro"` gives us JAX/CUDA. P100's HBM2 bandwidth and FP64 throughput matter for NUTS leapfrog steps; T4's FP16 strengths don't apply. numpyro doesn't auto-shard 2 chains across 2 T4s, so the second T4 would sit idle. TPU would require a JAX rewrite for the PyTorch LSTM and XGBoost — effort far exceeds the gain for a ~2–5 min pipeline.
#
# ### What we accelerate
# - **PyMC MCMC** → `nuts_sampler="numpyro"` (biggest win)
# - **PyTorch LSTM** → `.to("cuda")` (small model; modest gain)
# - **XGBoost** → **left on CPU** (only ~2500 rows; CUDA is slower here)
# - **Monte Carlo brackets** → already parallelized via multiprocessing

# %% [markdown]
# ## Cell 1 — Environment check

# %%
# !nvidia-smi --query-gpu=name,memory.total,driver_version --format=csv
import sys, platform
print(sys.version)
print(platform.platform())
# Out:
# name, memory.total [MiB], driver_version
# Tesla P100-PCIE-16GB, 16384 MiB, 580.105.08
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Linux-6.6.113+-x86_64-with-glibc2.35

# %% [markdown]
# ## Cell 2 — Install JAX + numpyro for GPU
#
# Kaggle's GPU image ships CUDA 12.x, PyTorch, and XGBoost preinstalled. We only add JAX+numpyro (for PyMC's GPU sampler) and pin PyMC/ArviZ to the versions in `requirements.txt`.

# %%
# !pip install -q --upgrade "jax[cuda12]" numpyro
# !pip install -q "pymc>=5.10,<6.0" "arviz>=0.17,<1.0" "nba_api>=1.4,<2.0" "plotly>=5.18,<6.0"

# P100 (sm_60) support was dropped in PyTorch 2.5.
# If the pre-installed version is >=2.5, downgrade to the last compatible build.
import torch
_major, _minor = (int(x) for x in torch.__version__.split(".")[:2])
if (_major, _minor) >= (2, 5):
    print(f"PyTorch {torch.__version__} does not support P100 (sm_60) — downgrading to 2.4.1")
    # !pip install -q torch==2.4.1 --index-url https://download.pytorch.org/whl/cu121
else:
    print(f"PyTorch {torch.__version__} supports P100 — no downgrade needed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 16.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 74.6 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 99.1 MB/s eta 0:00:00ta 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 MB 11.5 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 MB 18.1 MB/s eta 0:00:0000:0100:01m
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 34.5 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 9.3 MB/s eta 0:00:00:00:01
# PyTorch 2.10.0+cu128 does not support P100 (sm_60) — downgrading to 2.4.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 2.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 3.8 MB/s eta 0:00:00:00:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 51.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 108.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 12.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.6 MB/s eta 0:00:00:00:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 15.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 9.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 10.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 8.9 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.
# torchvision 0.25.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.

# %% [markdown]
# ## Cell 3 — Clone repo (main branch)

# %%
import os, sys, shutil
REPO_DIR = "/kaggle/working/nba-playoffs"
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR)
# !git clone --depth 1 --branch main https://github.com/ferhat00/nba-playoffs.git {REPO_DIR}
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)
os.chdir(REPO_DIR)
print("cwd:", os.getcwd())
# Out:
# Cloning into '/kaggle/working/nba-playoffs'...
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 27 (delta 0), reused 20 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 41.59 KiB | 13.86 MiB/s, done.
# cwd: /kaggle/working/nba-playoffs

# %% [markdown]
# ## Cell 4 — Verify CUDA is visible to PyTorch and JAX

# %%
import torch, jax
print("torch.cuda.is_available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("  device:", torch.cuda.get_device_name(0))
print("jax.devices:", jax.devices())
# Out:
# torch.cuda.is_available: True
#   device: Tesla P100-PCIE-16GB
# jax.devices: [CudaDevice(id=0)]
# E0420 16:08:49.251051     176 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 16:08:49.253719     176 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.

# %% [markdown]
# ## Cell 5 — Runtime monkey-patches
#
# All modifications are in-process (no file edits in the cloned repo). This keeps the notebook diffable and survives future upstream changes.
#
# - **(a)** Wrap `pm.sample` in `player_evaluator` so the existing call picks up `nuts_sampler="numpyro"`.
# - **(b)** In `TeamStateAggregator.build`, shim `torch.from_numpy` and the `_LSTMMomentum` class so tensors and model land on CUDA for the training loop.
# - **(c)** Force multiprocessing `spawn` start method to avoid fork-after-CUDA-init corruption when `bracket_simulator` forks workers.
# - **(d)** XGBoost is intentionally left on CPU (`device="cuda"` is slower on 2500 rows).

# %%
# (a) PyMC -> numpyro
import sys, os
REPO_DIR = "/kaggle/working/nba-playoffs"
if REPO_DIR not in sys.path:
    if not os.path.isdir(REPO_DIR):
        raise RuntimeError(f"{REPO_DIR} not found — run Cell 3 (clone repo) first")
    sys.path.insert(0, REPO_DIR)
    
from nba_playoff_predictor.models import player_evaluator as pe
import pymc as pm

_orig_sample = pm.sample
def _gpu_sample(*args, **kwargs):
    kwargs.setdefault("nuts_sampler", "numpyro")
    kwargs.setdefault("progressbar", False)
    return _orig_sample(*args, **kwargs)
pe.pm.sample = _gpu_sample
print("patched: player_evaluator.pm.sample -> numpyro")
# Out:
# patched: player_evaluator.pm.sample -> numpyro

# %%
# (b) PyTorch LSTM -> CUDA (with compatibility probe)
from nba_playoff_predictor.models import team_aggregator as ta
import torch

_DEVICE = torch.device("cpu")
if torch.cuda.is_available():
    try:
        # Probe: launch a trivial kernel to verify sm_XX compatibility
        torch.tensor([1.0], device="cuda").sum()
        _DEVICE = torch.device("cuda")
    except RuntimeError as e:
        print(f"⚠ PyTorch CUDA kernels incompatible with this GPU — LSTM stays on CPU")
        print(f"  ({e})")

_orig_build = ta.TeamStateAggregator.build

def _gpu_build(self, *a, **kw):
    real_from_numpy = ta.torch.from_numpy
    real_lstm_cls = ta._LSTMMomentum

    def _from_numpy_cuda(arr):
        return real_from_numpy(arr).to(_DEVICE)

    class _LSTMCuda(real_lstm_cls):
        def __init__(self, *aa, **kk):
            super().__init__(*aa, **kk)
            self.to(_DEVICE)

    ta.torch.from_numpy = _from_numpy_cuda
    ta._LSTMMomentum = _LSTMCuda
    try:
        return _orig_build(self, *a, **kw)
    finally:
        ta.torch.from_numpy = real_from_numpy
        ta._LSTMMomentum = real_lstm_cls

ta.TeamStateAggregator.build = _gpu_build
print("patched: TeamStateAggregator.build -> device =", _DEVICE)
# Out:
# patched: TeamStateAggregator.build -> device = cuda

# %%
# (c) Multiprocessing safety: avoid fork-after-CUDA-init
import multiprocessing as mp
try:
    mp.set_start_method("spawn", force=True)
    print("mp start method ->", mp.get_start_method())
except RuntimeError as e:
    print("mp start method already set:", mp.get_start_method(), "|", e)
# Out:
# mp start method -> spawn

# %% [markdown]
# ## Cell 6 — Run the pipeline (in-process)
#
# We import and call `run()` directly instead of `!python -m nba_playoff_predictor.main`. A subprocess would not inherit the monkey-patches above.
#
# Run once with `QUICK = True` first (<60s smoke test), then flip to `QUICK = False` for the full 100k-sim run.

# %%
from nba_playoff_predictor.main import run, _configure_logging, _set_seeds

_configure_logging(verbose=True)
_set_seeds(42)

QUICK = False  # set False for the full 100k-sim / 500-MCMC-draw run

if QUICK:
    run(n_simulations=1_000, mcmc_samples=100)
else:
    run(n_simulations=100_000, mcmc_samples=500)
# Out:
# 16:09:17 | INFO    | nba_playoff_predictor.main | Step 1/6: fetching data
# 16:09:17 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashTeamStats (advanced) for 2024-25...
# 16:09:49 | WARNING | nba_playoff_predictor.data.fetcher | nba_api call failed (attempt 1/3): HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1.0s.
# 16:09:50 | INFO    | nba_playoff_predictor.data.fetcher | Fetched team stats for 16 teams via nba_api
# 16:09:50 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashPlayerStats (per36) for 2024-25...
# 16:09:50 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashPlayerStats (advanced) for 2024-25...
# 16:09:50 | WARNING | nba_playoff_predictor.data.fetcher | PlayerInjurySummary unavailable (cannot import name 'PlayerInjurySummary' from 'nba_api.stats.endpoints' (/usr/local/lib/python3.12/dist-packages/nba_api/stats/endpoints/__init__.py)); no injuries applied
# 16:09:50 | INFO    | nba_playoff_predictor.data.fetcher | Fetched player stats for 290 players via nba_api
# 16:09:50 | INFO    | nba_playoff_predictor.main | Loaded 16 teams, 290 players
# 16:09:50 | INFO    | nba_playoff_predictor.main | Step 2/6: fitting BayesianPlayerEvaluator (MCMC samples=500)
# 16:09:50 | INFO    | nba_playoff_predictor.models.player_evaluator | Fitting BayesianPlayerEvaluator on 290 players across 16 teams
# E0420 16:09:52.145545     176 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 16:09:52.164808     176 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 16:09:52.197384     176 status_macros.cc:58] INTERNAL: RET_CHECK failure (external/xla/xla/service/gpu/gpu_compiler.cc:2695) dnn_support != nullptr
# *** Begin stack trace ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	PyObject_Vectorcall
# 	_PyEval_EvalFrameDefault
# 	PyObject_Vectorcall
#
#
#
# 	_PyObject_FastCallDictTstate
# 	_PyObject_Call_Prepend
#
# 	_PyObject_MakeTpCall
# 	_PyEval_EvalFrameDefault
# 	PyObject_Vectorcall
#
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyObject_Call
# 	_PyEval_EvalFrameDefault
# 	PyEval_EvalCode
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyObject_Call
# 	_PyEval_EvalFrameDefault
#
#
#
#
#
#
#
# 	_PyEval_EvalFrameDefault
# 	PyEval_EvalCode
#
#
# 	PyObject_Vectorcall
# 	_PyEval_EvalFrameDefault
#
# 	Py_RunMain
# 	Py_BytesMain
#
# 	__libc_start_main
# 	_start
# *** End stack trace ***
#
# 16:09:52 | WARNING | nba_playoff_predictor.models.player_evaluator | PyMC sampling failed (INTERNAL: RET_CHECK failure (external/xla/xla/service/gpu/gpu_compiler.cc:2695) dnn_support != nullptr ); using closed-form fallback
# 16:09:52 | WARNING | nba_playoff_predictor.models.player_evaluator | Using closed-form shrinkage estimator instead of PyMC.
# 16:09:52 | INFO    | nba_playoff_predictor.models.player_evaluator | BayesianPlayerEvaluator fit complete
# 16:09:52 | INFO    | nba_playoff_predictor.main | Top-5 East impact: Giannis Antetokounmpo (MIL, +1.34); Tolu Smith (DET, +0.92); Karl-Anthony Towns (NYK, +0.91); Evan Mobley (CLE, +0.84); Jayson Tatum (BOS, +0.80)
# 16:09:52 | INFO    | nba_playoff_predictor.main | Top-5 West impact: Shai Gilgeous-Alexander (OKC, +1.35); Nikola Jokić (DEN, +1.30); Anthony Davis (DAL, +0.87); Luka Dončić (LAL, +0.86); Chet Holmgren (OKC, +0.79)
# 16:09:52 | INFO    | nba_playoff_predictor.main | Step 3/6: building TeamStateAggregator
# 16:09:54 | INFO    | nba_playoff_predictor.models.team_aggregator | LSTM momentum trained (15 epochs, final loss=0.6436)
# 16:09:54 | INFO    | nba_playoff_predictor.models.team_aggregator | TeamStateAggregator built for 16 teams
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[ATL] Atlanta Hawks: [ 1.484e+03,  1.484e+03,  6.087e-02, -9.591e-01, -1.208e+00,  1.888e+00,
#   3.801e-01, -8.281e-03]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[BOS] Boston Celtics: [ 1.641e+03,  1.641e+03,  1.809e-03,  1.433e+00,  9.298e-01, -1.652e+00,
#   6.359e-01, -1.166e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[CLE] Cleveland Cavaliers: [1.638e+03, 1.638e+03, 8.979e-02, 2.052e+00, 1.564e-01, 2.787e-01,
#  7.605e-01, 2.251e-03]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[DAL] Dallas Mavericks: [ 1.480e+03,  1.480e+03,  5.847e-03, -9.591e-01, -1.299e+00,  1.956e-01,
#   7.011e-01, -3.842e-02]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[DEN] Denver Nuggets: [ 1.557e+03,  1.557e+03,  5.351e-02,  1.186e+00, -1.345e+00,  4.656e-01,
#   6.558e-01, -2.479e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[DET] Detroit Pistons: [ 1.532e+03,  1.532e+03,  4.204e-02, -5.878e-01, -1.621e-01,  2.579e-01,
#   7.257e-01,  2.864e-02]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[GSW] Golden State Warriors: [ 1.548e+03,  1.548e+03,  7.524e-02, -7.528e-01,  5.204e-01, -2.093e-01,
#   4.493e-01,  5.796e-02]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[HOU] Houston Rockets: [ 1.569e+03,  1.569e+03,  4.640e-02, -4.641e-01,  8.388e-01, -3.858e-01,
#   6.170e-01,  1.101e-02]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[IND] Indiana Pacers: [ 1.532e+03,  1.532e+03,  8.619e-02, -2.578e-01, -5.260e-01,  5.123e-01,
#   5.055e-01,  6.684e-03]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[LAC] LA Clippers: [ 1.574e+03,  1.574e+03,  7.223e-02, -7.116e-01,  1.248e+00, -7.959e-01,
#   4.872e-01, -1.809e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[LAL] Los Angeles Lakers: [ 1.518e+03,  1.518e+03, -2.077e-04, -4.228e-01, -7.535e-01, -7.440e-01,
#   4.497e-01, -6.972e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[MEM] Memphis Grizzlies: [ 1.570e+03,  1.570e+03,  1.204e-03,  4.847e-01, -2.076e-01,  2.033e+00,
#   6.387e-01,  2.099e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[MIA] Miami Heat: [ 1.506e+03,  1.506e+03, -7.640e-03, -1.495e+00,  6.540e-02, -1.398e+00,
#   2.689e-01, -1.881e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[MIL] Milwaukee Bucks: [ 1.536e+03,  1.536e+03,  1.031e-01, -3.816e-01, -2.531e-01,  7.625e-02,
#   7.622e-01, -2.741e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[NYK] New York Knicks: [ 1.560e+03,  1.560e+03,  6.648e-02,  5.259e-01, -5.260e-01, -1.107e+00,
#   4.867e-01, -3.640e-01]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Vector[OKC] Oklahoma City Thunder: [1.690e+03, 1.690e+03, 6.689e-02, 1.310e+00, 2.522e+00, 5.850e-01,
#  9.530e-01, 3.088e-02]
# 16:09:54 | INFO    | nba_playoff_predictor.main | Step 4/6: training XGBoostMatchupEngine
# 16:09:54 | INFO    | nba_playoff_predictor.models.matchup_predictor | No historical matchup data supplied; generating 2500 synthetic samples
# 16:09:54 | INFO    | nba_playoff_predictor.models.matchup_predictor | XGBoostMatchupEngine holdout AUC: 0.7115
# 16:09:54 | INFO    | nba_playoff_predictor.main | Matchup engine holdout AUC: 0.7115
# 16:09:54 | INFO    | nba_playoff_predictor.main | Step 5/6: simulating 100000 brackets
# 16:09:54 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Precomputing 16x16 single-game win probability matrix...
# 16:09:54 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Running 100000 simulations across 3 workers...
# Simulation batches: 100%|██████████| 3/3 [00:04<00:00,  1.51s/it]
# 16:09:59 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Simulation complete
# 16:09:59 | INFO    | nba_playoff_predictor.main | Step 6/6: writing outputs
# === 2025 NBA Playoff — Championship Probabilities ===
#                  team  championship%  finals%  conf_finals%  second_round%
# Oklahoma City Thunder          65.20    99.84         99.94         100.00
#   Cleveland Cavaliers          18.83    58.53         95.06          99.54
#        Boston Celtics          15.95    38.51         84.17          99.99
#       Houston Rockets           0.01     0.10         34.12          41.76
#        Denver Nuggets           0.01     0.03          0.06          91.01
#     Memphis Grizzlies           0.00     0.02         53.41          58.24
#        Indiana Pacers           0.00     0.66          2.14          44.39
#       New York Knicks           0.00     1.76         14.27          90.93
#       Milwaukee Bucks           0.00     0.42          2.65          55.61
#            Miami Heat           0.00     0.05          0.15           0.46
#       Detroit Pistons           0.00     0.06          1.55           9.07
#         Atlanta Hawks           0.00     0.00          0.00           0.01
#    Los Angeles Lakers           0.00     0.01          7.35          73.14
#           LA Clippers           0.00     0.00          0.00           8.99
# Golden State Warriors           0.00     0.00          5.12          26.86
#      Dallas Mavericks           0.00     0.00          0.00           0.00
# 16:09:59 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Wrote bracket visualization to output/bracket_probabilities.html
# 16:09:59 | INFO    | nba_playoff_predictor.main | Saved bracket visualization: output/bracket_probabilities.html

# %% [markdown]
# ## Cell 7 — Display outputs

# %%
from pathlib import Path
from IPython.display import Image, HTML, display

out_dir = Path(REPO_DIR) / "output"
if not out_dir.exists():
    print("No output/ directory yet — did the run complete?")
else:
    for p in sorted(out_dir.glob("*")):
        print(p)
        if p.suffix.lower() in (".png", ".jpg", ".jpeg"):
            display(Image(str(p)))
        elif p.suffix.lower() == ".html":
            display(HTML(p.read_text()))
# Out:
# /kaggle/working/nba-playoffs/output/bracket_probabilities.html
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a053bb94-acc2-4931-baee-360d1d9d4aa3" class="plotly-graph-div" style="height:720px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a053bb94-acc2-4931-baee-360d1d9d4aa3")) {                    Plotly.newPlot(                        "a053bb94-acc2-4931-baee-360d1d9d4aa3",                        [{"hoverinfo":"skip","line":{"color":"rgba(120,120,120,0.45)","width":1.5},"mode":"lines","showlegend":false,"x":[-4,-3,null,-4,-3,null,-4,-3,null,-4,-3,null,-4,-3,null,-4,-3,null,-4,-3,null,-4,-3,null,-3,-2,null,-3,-2,null,-3,-2,null,-3,-2,null,-2,-1,null,-2,-1,null,4,3,null,4,3,null,4,3,null,4,3,null,4,3,null,4,3,null,4,3,null,4,3,null,3,2,null,3,2,null,3,2,null,3,2,null,2,1,null,2,1,null,-1,0,null,1,0,null],"y":[7,6.5,null,6,6.5,null,5,4.5,null,4,4.5,null,3,2.5,null,2,2.5,null,1,0.5,null,0,0.5,null,6.5,5.5,null,4.5,5.5,null,2.5,1.5,null,0.5,1.5,null,5.5,3.5,null,1.5,3.5,null,7,6.5,null,6,6.5,null,5,4.5,null,4,4.5,null,3,2.5,null,2,2.5,null,1,0.5,null,0,0.5,null,6.5,5.5,null,4.5,5.5,null,2.5,1.5,null,0.5,1.5,null,5.5,3.5,null,1.5,3.5,null,3.5,3.5,null,3.5,3.5,null],"type":"scatter"},{"hoverinfo":"text","hovertext":["Oklahoma City Thunder\u003cbr\u003eSeed: 1 (West)\u003cbr\u003eSecond round: 100.00%\u003cbr\u003eConf finals: 95.90%\u003cbr\u003eFinals: 95.90%\u003cbr\u003eChampionship: 68.70%","Dallas Mavericks\u003cbr\u003eSeed: 8 (West)\u003cbr\u003eSecond round: 0.00%\u003cbr\u003eConf finals: 0.00%\u003cbr\u003eFinals: 0.00%\u003cbr\u003eChampionship: 0.00%","Denver Nuggets\u003cbr\u003eSeed: 4 (West)\u003cbr\u003eSecond round: 92.50%\u003cbr\u003eConf finals: 4.10%\u003cbr\u003eFinals: 2.10%\u003cbr\u003eChampionship: 0.60%","LA Clippers\u003cbr\u003eSeed: 5 (West)\u003cbr\u003eSecond round: 7.50%\u003cbr\u003eConf finals: 0.00%\u003cbr\u003eFinals: 0.00%\u003cbr\u003eChampionship: 0.00%","Los Angeles Lakers\u003cbr\u003eSeed: 3 (West)\u003cbr\u003eSecond round: 81.00%\u003cbr\u003eConf finals: 13.40%\u003cbr\u003eFinals: 0.20%\u003cbr\u003eChampionship: 0.00%","Golden State Warriors\u003cbr\u003eSeed: 6 (West)\u003cbr\u003eSecond round: 19.00%\u003cbr\u003eConf finals: 3.40%\u003cbr\u003eFinals: 0.00%\u003cbr\u003eChampionship: 0.00%","Houston Rockets\u003cbr\u003eSeed: 2 (West)\u003cbr\u003eSecond round: 34.10%\u003cbr\u003eConf finals: 26.90%\u003cbr\u003eFinals: 0.30%\u003cbr\u003eChampionship: 0.00%","Memphis Grizzlies\u003cbr\u003eSeed: 7 (West)\u003cbr\u003eSecond round: 65.90%\u003cbr\u003eConf finals: 56.30%\u003cbr\u003eFinals: 1.50%\u003cbr\u003eChampionship: 0.00%","R2 slot\u003cbr\u003eThunder: reach R2 100.0%\u003cbr\u003eMavericks: reach R2 0.0%","R2 slot\u003cbr\u003eNuggets: reach R2 92.5%\u003cbr\u003eClippers: reach R2 7.5%","R2 slot\u003cbr\u003eLakers: reach R2 81.0%\u003cbr\u003eWarriors: reach R2 19.0%","R2 slot\u003cbr\u003eRockets: reach R2 34.1%\u003cbr\u003eGrizzlies: reach R2 65.9%","CF slot\u003cbr\u003eThunder: reach CF 95.9%\u003cbr\u003eMavericks: reach CF 0.0%\u003cbr\u003eNuggets: reach CF 4.1%\u003cbr\u003eClippers: reach CF 0.0%","CF slot\u003cbr\u003eLakers: reach CF 13.4%\u003cbr\u003eWarriors: reach CF 3.4%\u003cbr\u003eRockets: reach CF 26.9%\u003cbr\u003eGrizzlies: reach CF 56.3%","West Finals\u003cbr\u003eThunder: Finals 95.9%\u003cbr\u003eRockets: Finals 0.3%\u003cbr\u003eLakers: Finals 0.2%\u003cbr\u003eNuggets: Finals 2.1%\u003cbr\u003eClippers: Finals 0.0%\u003cbr\u003eWarriors: Finals 0.0%\u003cbr\u003eGrizzlies: Finals 1.5%\u003cbr\u003eMavericks: Finals 0.0%","Cleveland Cavaliers\u003cbr\u003eSeed: 1 (East)\u003cbr\u003eSecond round: 99.90%\u003cbr\u003eConf finals: 88.00%\u003cbr\u003eFinals: 65.70%\u003cbr\u003eChampionship: 22.20%","Miami Heat\u003cbr\u003eSeed: 8 (East)\u003cbr\u003eSecond round: 0.10%\u003cbr\u003e ...

# %% [markdown]
# ## Cell 8 (optional) — Quick wall-clock benchmark
#
# Sanity check that the GPU path is actually helping. For the small `--quick` config, JAX compile warmup can erase the MCMC speedup — expect GPU to pay off at the full 500-draw config.

# %%
import time
t = time.perf_counter()
run(n_simulations=1_000, mcmc_samples=100)
print(f"quick run wall-clock: {time.perf_counter() - t:.1f}s")
