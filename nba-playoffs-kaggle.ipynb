# %% [markdown]
# # NBA Playoff Predictor — Kaggle (P100 GPU)
#
# Clones https://github.com/ferhat00/nba-playoffs (main), applies runtime CUDA monkey-patches, and runs the full pipeline.
#
# **Before running:** in Kaggle notebook settings set **Accelerator = GPU P100** and **Internet = On** (`nba_api` needs network; fallback data exists but real data is better).
#
# ### Why P100 (not T4x2, not TPU)
# The critical path is PyMC MCMC on the Bayesian player evaluator; switching to `nuts_sampler="numpyro"` gives us JAX/CUDA. P100's HBM2 bandwidth and FP64 throughput matter for NUTS leapfrog steps; T4's FP16 strengths don't apply. numpyro doesn't auto-shard 2 chains across 2 T4s, so the second T4 would sit idle. TPU would require a JAX rewrite for the PyTorch LSTM and XGBoost — effort far exceeds the gain for a ~2–5 min pipeline.
#
# ### What we accelerate
# - **PyMC MCMC** → `nuts_sampler="numpyro"` (biggest win)
# - **PyTorch LSTM** → `.to("cuda")` (small model; modest gain)
# - **XGBoost** → **left on CPU** (only ~2500 rows; CUDA is slower here)
# - **Monte Carlo brackets** → already parallelized via multiprocessing

# %% [markdown]
# ## Cell 1 — Environment check

# %%
# !nvidia-smi --query-gpu=name,memory.total,driver_version --format=csv
import sys, platform
print(sys.version)
print(platform.platform())
# Out:
# name, memory.total [MiB], driver_version
# Tesla P100-PCIE-16GB, 16384 MiB, 580.105.08
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# Linux-6.6.113+-x86_64-with-glibc2.35

# %% [markdown]
# ## Cell 2 — Install JAX + numpyro for GPU
#
# Kaggle's GPU image ships CUDA 12.x, PyTorch, and XGBoost preinstalled. We only add JAX+numpyro (for PyMC's GPU sampler) and pin PyMC/ArviZ to the versions in `requirements.txt`.

# %%
# !pip install -q --upgrade "jax[cuda12]" numpyro
# !pip install -q "pymc>=5.10,<6.0" "arviz>=0.17,<1.0" "nba_api>=1.4,<2.0" "plotly>=5.18,<6.0"

# P100 (sm_60) support was dropped in PyTorch 2.5.
# If the pre-installed version is >=2.5, downgrade to the last compatible build.
import torch
_major, _minor = (int(x) for x in torch.__version__.split(".")[:2])
if (_major, _minor) >= (2, 5):
    print(f"PyTorch {torch.__version__} does not support P100 (sm_60) — downgrading to 2.4.1")
    # !pip install -q torch==2.4.1 --index-url https://download.pytorch.org/whl/cu121
else:
    print(f"PyTorch {torch.__version__} supports P100 — no downgrade needed")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.3 MB/s eta 0:00:00:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 101.6 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 MB 11.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 MB 21.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 MB 46.2 MB/s eta 0:00:00:00:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gym<=0.25.2, but you have gym 0.26.2 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.6/322.6 kB 8.9 MB/s eta 0:00:00:00:01
# PyTorch 2.10.0+cu128 does not support P100 (sm_60) — downgrading to 2.4.1
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 MB 1.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 2.2 MB/s eta 0:00:00:00:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 44.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 100.0 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 15.8 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 35.1 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 15.3 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 9.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 7.6 MB/s eta 0:00:0000:0100:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 9.0 MB/s eta 0:00:0000:0100:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.
# torchvision 0.25.0+cu128 requires torch==2.10.0, but you have torch 2.4.1+cu121 which is incompatible.

# %% [markdown]
# ## Cell 3 — Clone repo (main branch)

# %%
import os, sys, shutil
REPO_DIR = "/kaggle/working/nba-playoffs"
if os.path.exists(REPO_DIR):
    shutil.rmtree(REPO_DIR)
# !git clone --depth 1 --branch main https://github.com/ferhat00/nba-playoffs.git {REPO_DIR}
if REPO_DIR not in sys.path:
    sys.path.insert(0, REPO_DIR)
os.chdir(REPO_DIR)
print("cwd:", os.getcwd())
# Out:
# Cloning into '/kaggle/working/nba-playoffs'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 26 (delta 0), reused 21 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (26/26), 33.32 KiB | 8.33 MiB/s, done.
# cwd: /kaggle/working/nba-playoffs

# %% [markdown]
# ## Cell 4 — Verify CUDA is visible to PyTorch and JAX

# %%
import torch, jax
print("torch.cuda.is_available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("  device:", torch.cuda.get_device_name(0))
print("jax.devices:", jax.devices())
# Out:
# torch.cuda.is_available: True
#   device: Tesla P100-PCIE-16GB
# jax.devices: [CudaDevice(id=0)]
# E0420 14:54:03.055669     181 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 14:54:03.058204     181 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.

# %% [markdown]
# ## Cell 5 — Runtime monkey-patches
#
# All modifications are in-process (no file edits in the cloned repo). This keeps the notebook diffable and survives future upstream changes.
#
# - **(a)** Wrap `pm.sample` in `player_evaluator` so the existing call picks up `nuts_sampler="numpyro"`.
# - **(b)** In `TeamStateAggregator.build`, shim `torch.from_numpy` and the `_LSTMMomentum` class so tensors and model land on CUDA for the training loop.
# - **(c)** Force multiprocessing `spawn` start method to avoid fork-after-CUDA-init corruption when `bracket_simulator` forks workers.
# - **(d)** XGBoost is intentionally left on CPU (`device="cuda"` is slower on 2500 rows).

# %%
# (a) PyMC -> numpyro
import sys, os
REPO_DIR = "/kaggle/working/nba-playoffs"
if REPO_DIR not in sys.path:
    if not os.path.isdir(REPO_DIR):
        raise RuntimeError(f"{REPO_DIR} not found — run Cell 3 (clone repo) first")
    sys.path.insert(0, REPO_DIR)
    
from nba_playoff_predictor.models import player_evaluator as pe
import pymc as pm

_orig_sample = pm.sample
def _gpu_sample(*args, **kwargs):
    kwargs.setdefault("nuts_sampler", "numpyro")
    kwargs.setdefault("progressbar", False)
    return _orig_sample(*args, **kwargs)
pe.pm.sample = _gpu_sample
print("patched: player_evaluator.pm.sample -> numpyro")
# Out:
# patched: player_evaluator.pm.sample -> numpyro

# %%
# (b) PyTorch LSTM -> CUDA (with compatibility probe)
from nba_playoff_predictor.models import team_aggregator as ta
import torch

_DEVICE = torch.device("cpu")
if torch.cuda.is_available():
    try:
        # Probe: launch a trivial kernel to verify sm_XX compatibility
        torch.tensor([1.0], device="cuda").sum()
        _DEVICE = torch.device("cuda")
    except RuntimeError as e:
        print(f"⚠ PyTorch CUDA kernels incompatible with this GPU — LSTM stays on CPU")
        print(f"  ({e})")

_orig_build = ta.TeamStateAggregator.build

def _gpu_build(self, *a, **kw):
    real_from_numpy = ta.torch.from_numpy
    real_lstm_cls = ta._LSTMMomentum

    def _from_numpy_cuda(arr):
        return real_from_numpy(arr).to(_DEVICE)

    class _LSTMCuda(real_lstm_cls):
        def __init__(self, *aa, **kk):
            super().__init__(*aa, **kk)
            self.to(_DEVICE)

    ta.torch.from_numpy = _from_numpy_cuda
    ta._LSTMMomentum = _LSTMCuda
    try:
        return _orig_build(self, *a, **kw)
    finally:
        ta.torch.from_numpy = real_from_numpy
        ta._LSTMMomentum = real_lstm_cls

ta.TeamStateAggregator.build = _gpu_build
print("patched: TeamStateAggregator.build -> device =", _DEVICE)
# Out:
# patched: TeamStateAggregator.build -> device = cuda

# %%
# (c) Multiprocessing safety: avoid fork-after-CUDA-init
import multiprocessing as mp
try:
    mp.set_start_method("spawn", force=True)
    print("mp start method ->", mp.get_start_method())
except RuntimeError as e:
    print("mp start method already set:", mp.get_start_method(), "|", e)
# Out:
# mp start method -> spawn

# %% [markdown]
# ## Cell 6 — Run the pipeline (in-process)
#
# We import and call `run()` directly instead of `!python -m nba_playoff_predictor.main`. A subprocess would not inherit the monkey-patches above.
#
# Run once with `QUICK = True` first (<60s smoke test), then flip to `QUICK = False` for the full 100k-sim run.

# %%
from nba_playoff_predictor.main import run, _configure_logging, _set_seeds

_configure_logging(verbose=True)
_set_seeds(42)

QUICK = True  # set False for the full 100k-sim / 500-MCMC-draw run

if QUICK:
    run(n_simulations=1_000, mcmc_samples=100)
else:
    run(n_simulations=100_000, mcmc_samples=500)
# Out:
# 14:57:45 | INFO    | nba_playoff_predictor.main | Step 1/6: fetching data
# 14:57:45 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashTeamStats (advanced) for 2024-25...
# 14:58:16 | WARNING | nba_playoff_predictor.data.fetcher | nba_api call failed (attempt 1/3): HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1.0s.
# 14:58:17 | INFO    | nba_playoff_predictor.data.fetcher | Fetched team stats for 16 teams via nba_api
# 14:58:17 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashPlayerStats (per36) for 2024-25...
# 14:58:17 | INFO    | nba_playoff_predictor.data.fetcher | Fetching LeagueDashPlayerStats (advanced) for 2024-25...
# 14:58:17 | WARNING | nba_playoff_predictor.data.fetcher | PlayerInjurySummary unavailable (cannot import name 'PlayerInjurySummary' from 'nba_api.stats.endpoints' (/usr/local/lib/python3.12/dist-packages/nba_api/stats/endpoints/__init__.py)); no injuries applied
# 14:58:17 | INFO    | nba_playoff_predictor.data.fetcher | Fetched player stats for 290 players via nba_api
# 14:58:17 | INFO    | nba_playoff_predictor.main | Loaded 16 teams, 290 players
# 14:58:17 | INFO    | nba_playoff_predictor.main | Step 2/6: fitting BayesianPlayerEvaluator (MCMC samples=100)
# 14:58:17 | WARNING | nba_playoff_predictor.main | Running with fewer than 500 MCMC samples (100); posteriors will be noisier.
# 14:58:17 | INFO    | nba_playoff_predictor.models.player_evaluator | Fitting BayesianPlayerEvaluator on 290 players across 16 teams
# E0420 14:58:19.581853     181 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 14:58:19.600178     181 cuda_dnn.cc:454] Loaded runtime CuDNN library: 9.1.0 but source was compiled with: 9.8.0.  CuDNN library needs to have matching major version and equal or higher minor version. If using a binary install, upgrade your CuDNN library.  If building from sources, make sure the library loaded at runtime is compatible with the version specified during compile configuration.
# E0420 14:58:19.631261     181 status_macros.cc:58] INTERNAL: RET_CHECK failure (external/xla/xla/service/gpu/gpu_compiler.cc:2695) dnn_support != nullptr
# *** Begin stack trace ***
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	PyObject_Vectorcall
# 	_PyEval_EvalFrameDefault
# 	PyObject_Vectorcall
#
#
#
# 	_PyObject_FastCallDictTstate
# 	_PyObject_Call_Prepend
#
# 	_PyObject_MakeTpCall
# 	_PyEval_EvalFrameDefault
# 	PyObject_Vectorcall
#
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyObject_Call
# 	_PyEval_EvalFrameDefault
# 	PyEval_EvalCode
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyEval_EvalFrameDefault
#
#
# 	_PyObject_Call
# 	_PyEval_EvalFrameDefault
#
#
#
#
#
#
#
# 	_PyEval_EvalFrameDefault
# 	PyEval_EvalCode
#
#
# 	PyObject_Vectorcall
# 	_PyEval_EvalFrameDefault
#
# 	Py_RunMain
# 	Py_BytesMain
#
# 	__libc_start_main
# 	_start
# *** End stack trace ***
#
# 14:58:19 | WARNING | nba_playoff_predictor.models.player_evaluator | PyMC sampling failed (INTERNAL: RET_CHECK failure (external/xla/xla/service/gpu/gpu_compiler.cc:2695) dnn_support != nullptr ); using closed-form fallback
# 14:58:19 | WARNING | nba_playoff_predictor.models.player_evaluator | Using closed-form shrinkage estimator instead of PyMC.
# 14:58:19 | INFO    | nba_playoff_predictor.models.player_evaluator | BayesianPlayerEvaluator fit complete
# 14:58:19 | INFO    | nba_playoff_predictor.main | Top-5 East impact: Giannis Antetokounmpo (MIL, +1.34); Tolu Smith (DET, +0.92); Karl-Anthony Towns (NYK, +0.91); Evan Mobley (CLE, +0.84); Jayson Tatum (BOS, +0.80)
# 14:58:19 | INFO    | nba_playoff_predictor.main | Top-5 West impact: Shai Gilgeous-Alexander (OKC, +1.35); Nikola Jokić (DEN, +1.30); Anthony Davis (DAL, +0.87); Luka Dončić (LAL, +0.86); Chet Holmgren (OKC, +0.79)
# 14:58:19 | INFO    | nba_playoff_predictor.main | Step 3/6: building TeamStateAggregator
# 14:58:21 | INFO    | nba_playoff_predictor.models.team_aggregator | LSTM momentum trained (15 epochs, final loss=0.6436)
# 14:58:21 | INFO    | nba_playoff_predictor.models.team_aggregator | TeamStateAggregator built for 16 teams
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[ATL] Atlanta Hawks: [ 1.484e+03,  1.484e+03,  6.087e-02, -9.591e-01, -1.208e+00,  1.888e+00,
#   3.801e-01, -8.281e-03]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[BOS] Boston Celtics: [ 1.641e+03,  1.641e+03,  1.809e-03,  1.433e+00,  9.298e-01, -1.652e+00,
#   6.359e-01, -1.166e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[CLE] Cleveland Cavaliers: [1.638e+03, 1.638e+03, 8.979e-02, 2.052e+00, 1.564e-01, 2.787e-01,
#  7.605e-01, 2.251e-03]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[DAL] Dallas Mavericks: [ 1.480e+03,  1.480e+03,  5.847e-03, -9.591e-01, -1.299e+00,  1.956e-01,
#   7.011e-01, -3.842e-02]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[DEN] Denver Nuggets: [ 1.557e+03,  1.557e+03,  5.351e-02,  1.186e+00, -1.345e+00,  4.656e-01,
#   6.558e-01, -2.479e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[DET] Detroit Pistons: [ 1.532e+03,  1.532e+03,  4.204e-02, -5.878e-01, -1.621e-01,  2.579e-01,
#   7.257e-01,  2.864e-02]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[GSW] Golden State Warriors: [ 1.548e+03,  1.548e+03,  7.524e-02, -7.528e-01,  5.204e-01, -2.093e-01,
#   4.493e-01,  5.796e-02]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[HOU] Houston Rockets: [ 1.569e+03,  1.569e+03,  4.640e-02, -4.641e-01,  8.388e-01, -3.858e-01,
#   6.170e-01,  1.101e-02]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[IND] Indiana Pacers: [ 1.532e+03,  1.532e+03,  8.619e-02, -2.578e-01, -5.260e-01,  5.123e-01,
#   5.055e-01,  6.684e-03]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[LAC] LA Clippers: [ 1.574e+03,  1.574e+03,  7.223e-02, -7.116e-01,  1.248e+00, -7.959e-01,
#   4.872e-01, -1.809e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[LAL] Los Angeles Lakers: [ 1.518e+03,  1.518e+03, -2.077e-04, -4.228e-01, -7.535e-01, -7.440e-01,
#   4.497e-01, -6.972e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[MEM] Memphis Grizzlies: [ 1.570e+03,  1.570e+03,  1.204e-03,  4.847e-01, -2.076e-01,  2.033e+00,
#   6.387e-01,  2.099e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[MIA] Miami Heat: [ 1.506e+03,  1.506e+03, -7.640e-03, -1.495e+00,  6.540e-02, -1.398e+00,
#   2.689e-01, -1.881e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[MIL] Milwaukee Bucks: [ 1.536e+03,  1.536e+03,  1.031e-01, -3.816e-01, -2.531e-01,  7.625e-02,
#   7.622e-01, -2.741e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[NYK] New York Knicks: [ 1.560e+03,  1.560e+03,  6.648e-02,  5.259e-01, -5.260e-01, -1.107e+00,
#   4.867e-01, -3.640e-01]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Vector[OKC] Oklahoma City Thunder: [1.690e+03, 1.690e+03, 6.689e-02, 1.310e+00, 2.522e+00, 5.850e-01,
#  9.530e-01, 3.088e-02]
# 14:58:21 | INFO    | nba_playoff_predictor.main | Step 4/6: training XGBoostMatchupEngine
# 14:58:21 | INFO    | nba_playoff_predictor.models.matchup_predictor | No historical matchup data supplied; generating 2500 synthetic samples
# 14:58:22 | INFO    | nba_playoff_predictor.models.matchup_predictor | XGBoostMatchupEngine holdout AUC: 0.7115
# 14:58:22 | INFO    | nba_playoff_predictor.main | Matchup engine holdout AUC: 0.7115
# 14:58:22 | INFO    | nba_playoff_predictor.main | Step 5/6: simulating 1000 brackets
# 14:58:22 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Precomputing 16x16 single-game win probability matrix...
# 14:58:22 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Running 1000 simulations across 3 workers...
# Simulation batches: 100%|██████████| 3/3 [00:00<00:00, 34.76it/s]
# 14:58:22 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Simulation complete
# 14:58:22 | INFO    | nba_playoff_predictor.main | Step 6/6: writing outputs
# === 2025 NBA Playoff — Championship Probabilities ===
#                  team  championship%  finals%  conf_finals%  second_round%
# Oklahoma City Thunder          67.60    99.80         99.80         100.00
#   Cleveland Cavaliers          16.50    57.30         94.20          99.30
#        Boston Celtics          15.90    39.90         85.00         100.00
#       New York Knicks           0.00     1.70         14.30          91.50
#       Milwaukee Bucks           0.00     0.40          2.60          53.70
#       Detroit Pistons           0.00     0.00          0.70           8.50
#         Atlanta Hawks           0.00     0.00          0.00           0.00
#        Indiana Pacers           0.00     0.60          2.80          46.30
#            Miami Heat           0.00     0.10          0.40           0.70
#       Houston Rockets           0.00     0.00         32.70          39.80
#    Los Angeles Lakers           0.00     0.00          7.20          72.50
#        Denver Nuggets           0.00     0.20          0.20          90.60
#           LA Clippers           0.00     0.00          0.00           9.40
# Golden State Warriors           0.00     0.00          5.70          27.50
#     Memphis Grizzlies           0.00     0.00         54.40          60.20
#      Dallas Mavericks           0.00     0.00          0.00           0.00
# 14:58:22 | INFO    | nba_playoff_predictor.simulation.bracket_simulator | Wrote bracket visualization to output/bracket_probabilities.html
# 14:58:22 | INFO    | nba_playoff_predictor.main | Saved bracket visualization: output/bracket_probabilities.html

# %% [markdown]
# ## Cell 7 — Display outputs

# %%
from pathlib import Path
from IPython.display import Image, HTML, display

out_dir = Path(REPO_DIR) / "output"
if not out_dir.exists():
    print("No output/ directory yet — did the run complete?")
else:
    for p in sorted(out_dir.glob("*")):
        print(p)
        if p.suffix.lower() in (".png", ".jpg", ".jpeg"):
            display(Image(str(p)))
        elif p.suffix.lower() == ".html":
            display(HTML(p.read_text()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/1778490564.py in <cell line: 0>()
#       2 from IPython.display import Image, HTML, display
#       3
# ----> 4 out_dir = Path(REPO_DIR) / "output"
#       5 if not out_dir.exists():
#       6     print("No output/ directory yet — did the run complete?")
#
# NameError: name 'REPO_DIR' is not defined

# %% [markdown]
# ## Cell 8 (optional) — Quick wall-clock benchmark
#
# Sanity check that the GPU path is actually helping. For the small `--quick` config, JAX compile warmup can erase the MCMC speedup — expect GPU to pay off at the full 500-draw config.

# %%
import time
t = time.perf_counter()
run(n_simulations=1_000, mcmc_samples=100)
print(f"quick run wall-clock: {time.perf_counter() - t:.1f}s")
